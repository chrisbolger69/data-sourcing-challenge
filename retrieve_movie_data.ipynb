# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv('.env')

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:Movies AND type_of_material:Review AND headline:love'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

query_url = url+'api-key='+nyt_api_key+'&fq='+filter_query+'&sort='+sort+'&fl='+field_list+'&begin_date='+begin_date+'&end_date='+end_date

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):  

    # create query with a page number
    # API results show 10 articles at a time
    query_url2 = query_url+'&page=1'
    
    # Make a "GET" request and retrieve the JSON
    reviews = requests.get(query_url2).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
   
        # Print the page that was just retrieved
        print(f"A page with results: {page}")
    except:
        # Print the page number that had no results then break from the loop
        print(f"A page with no results: {page}")
        break
# Out:
# A page with results: 0
# A page with results: 1
# A page with results: 2
# A page with results: 3
# A page with results: 4
# A page with results: 5
# A page with results: 6
# A page with results: 7
# A page with results: 8
# A page with results: 9
# A page with results: 10
# A page with results: 11
# A page with results: 12
# A page with results: 13
# A page with results: 14
# A page with results: 15
# A page with results: 16
# A page with results: 17
# A page with results: 18
# A page with results: 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
for item in range(5):
    print(f"Item {item}: {json.dumps(reviews_list[item], indent=4)}")
# Out:
# Item 0: {
#     "web_url": "https://www.nytimes.com/2023/01/31/movies/pamela-a-love-story-review.html",
#     "snippet": "This documentary from Ryan White rewinds, to powerful effect, on Pamela Anderson\u2019s life and fame.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018Pamela, a Love Story\u2019 Review: A Frank Look Back",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "Pamela, a Love Story",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Documentary Films and Programs",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Anderson, Pamela (1967- )",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "White, Ryan (Filmmaker)",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "Pamela, a Love Story (Movie)",
#             "rank": 4,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-01-31T12:00:05+0000",
#     "byline": {
#         "original": "By Glenn Kenny",
#         "person": [
#             {
#                 "firstname": "Glenn",
#                 "middlename": null,
#                 "lastname": "Kenny",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 295
# }
# Item 1: {
#     "web_url": "https://www.nytimes.com/2023/01/19/movies/in-from-the-side-review.html",
#     "snippet": "In Matt Carter\u2019s gay rugby film, sports and romance smash together like two players from opposing teams.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018In From the Side\u2019 Review: Love and Rugby Play a Losing Game",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "In From the Side",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "In From the Side (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Carter, Matt (Filmmaker)",
#             "rank": 3,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-01-19T17:50:16+0000",
#     "byline": {
#         "original": "By Kyle Turner",
#         "person": [
#             {
#                 "firstname": "Kyle",
#                 "middlename": null,
#                 "lastname": "Turner",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 281
# }
# Item 2: {
#     "web_url": "https://www.nytimes.com/2023/01/19/movies/after-love-review.html",
#     "snippet": "In this intelligent melodrama by the director Aleem Khan, a British woman discovers her husband has been leading a double life.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018After Love\u2019 Review: The Other Woman",
#         "kicker": "Critic\u2019s Pick",
#         "content_kicker": null,
#         "print_headline": "After Love",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "After Love (2020) (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Khan, Aleem",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Scanlan, Joanna (1961- )",
#             "rank": 4,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-01-19T12:00:06+0000",
#     "byline": {
#         "original": "By Beatrice Loayza",
#         "person": [
#             {
#                 "firstname": "Beatrice",
#                 "middlename": null,
#                 "lastname": "Loayza",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 359
# }
# Item 3: {
#     "web_url": "https://www.nytimes.com/2023/01/05/movies/alcarras-review.html",
#     "snippet": "In this naturalistic drama from Spain, a family confronts the impending loss of its generations-old farm.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018Alcarr\u00e0s\u2019 Review: Labor of Love",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "Alcarr\u00e0s",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Simon, Carla",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "Alcarras (Movie)",
#             "rank": 3,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-01-05T12:00:03+0000",
#     "byline": {
#         "original": "By Devika Girish",
#         "person": [
#             {
#                 "firstname": "Devika",
#                 "middlename": null,
#                 "lastname": "Girish",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 306
# }
# Item 4: {
#     "web_url": "https://www.nytimes.com/2022/12/15/movies/nelly-and-nadine-review.html",
#     "snippet": "A family archive provides intimate records of a love affair that began between two women imprisoned in the Ravensbr\u00fcck concentration camp.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018Nelly & Nadine\u2019 Review: An Unlikely Love, an Unlikely Record",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "Nelly &amp; Nadine",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Documentary Films and Programs",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Gertten, Magnus",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "Nelly & Nadine (Movie)",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "subject",
#             "value": "Content Type: Personal Profile",
#             "rank": 4,
#             "major": "N"
#         },
#         {
#             "name": "subject",
#             "value": "Holocaust and the Nazi Era",
#             "rank": 5,
#             "major": "N"
#         },
#         {
#             "name": "subject",
#             "value": "World War II (1939-45)",
#             "rank": 6,
#             "major": "N"
#         },
#         {
#             "name": "subject",
#             "value": "Women and Girls",
#             "rank": 7,
#             "major": "N"
#         },
#         {
#             "name": "subject",
#             "value": "Homosexuality and Bisexuality",
#             "rank": 8,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2022-12-15T12:00:04+0000",
#     "byline": {
#         "original": "By Teo Bugbee",
#         "person": [
#             {
#                 "firstname": "Teo",
#                 "middlename": null,
#                 "lastname": "Bugbee",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 308
# }

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
reviews_df['title'] = reviews_df['headline.main'].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])

# %%
# Extract 'name' and 'value' from items in "keywords" column
# Fix the "keywords" column by converting cells from a list to a string
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

reviews_df['keywords'] = reviews_df['keywords'].apply(extract_keywords)

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = reviews_df['title'].to_list()

# %% [markdown]
# ### Access The Movie Database API

# %%
## Prepareing The Movie Database query ##
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

## Creating  an empty list to store everything in ##
tmdb_movies_list = []

# Createing a request counter to sleep the requests after a multiple
# of 50 requests per call ##
request_counter = 1

## Looping through the titles ##
for title in titles:
    ## Checking if we need to sleep at all before making a request##
    if request_counter % 50 == 0:
        time.sleep(1)
        print(f"Sleeping at {request_counter} requests")
    
    ## Add 1 to the request counter ##
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    response = requests.get(url + title + tmdb_key_string)
    data = response.json()
    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        movie_id = data["results"][0]["id"]
        
        # Make a request for a the full movie details
        query_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
        
        # Execute "GET" request with url
        data = requests.get(query_url).json()
        
        # Extract the genre names into a list
        genres = []
        for genre in data['genres']:
            genres.append(
                genre["name"]
            )
        
        # Extract the spoken_languages' English name into a list
        spoken_languages = []
        for language in data['spoken_languages']:
            spoken_languages.append(
                language["english_name"]
            )
        
        # Extract the production_countries' name into a list
        production_countries = []
        for country in data['production_countries']:
            production_countries.append(
                country["name"]
            )
        
        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        tmdb_movies_list.append(
            {
                "title": data['title'],
                "original_title": data['original_title'],
                "budget": data['budget'],
                "genre": genres,
                "language": data['original_language'],
                "spoken_languages": spoken_languages,
                "homepage": data['homepage'],
                "overview": data['overview'],
                "popularity": data['popularity'],
                "runtime": data['runtime'],
                "revenue": data['revenue'],
                "release_date": data['release_date'],
                "vote_average": data['vote_average'],
                "vote_count": data['vote_count'],
                "production_countries": production_countries
            }
        )
        # Print out the title that was found
        print(f"Found {title}")
    except:
        print(title + " not found.")
# Out:
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Sleeping at 50 requests
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Sleeping at 100 requests
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Sleeping at 150 requests
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Sleeping at 200 requests
# Found My Policeman

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
for item in range(5):
    print(f"Item {item}: {json.dumps(tmdb_movies_list[item], indent=4)}")
# Out:
# Item 0: {
#     "title": "Pamela, A Love Story",
#     "original_title": "Pamela, A Love Story",
#     "budget": 0,
#     "genre": [
#         "Documentary"
#     ],
#     "language": "en",
#     "spoken_languages": [
#         "English"
#     ],
#     "homepage": "https://www.netflix.com/title/81590934",
#     "overview": "In her own words, through personal video and diaries, Pamela Anderson shares the story of her rise to fame, rocky romances and infamous sex tape scandal.",
#     "popularity": 17.091,
#     "runtime": 113,
#     "revenue": 0,
#     "release_date": "2023-01-30",
#     "vote_average": 7.0,
#     "vote_count": 202,
#     "production_countries": [
#         "United States of America"
#     ]
# }
# Item 1: {
#     "title": "In from the Side",
#     "original_title": "In from the Side",
#     "budget": 0,
#     "genre": [
#         "Drama",
#         "Romance"
#     ],
#     "language": "en",
#     "spoken_languages": [
#         "English"
#     ],
#     "homepage": "http://www.infromthesidemovie.com",
#     "overview": "Mark, a new and inexperienced rugby club member, finds himself drawn to Warren, a seasoned first team player. When a series of happenstances at an away fixture lead to a drunken encounter, Mark and Warren unwittingly embark on a romantic affair they struggle to hide from their partners and teammates.",
#     "popularity": 11.71,
#     "runtime": 134,
#     "revenue": 0,
#     "release_date": "2022-09-16",
#     "vote_average": 6.78,
#     "vote_count": 59,
#     "production_countries": [
#         "United Kingdom"
#     ]
# }
# Item 2: {
#     "title": "After Love",
#     "original_title": "After Love",
#     "budget": 0,
#     "genre": [
#         "Drama"
#     ],
#     "language": "en",
#     "spoken_languages": [
#         "English",
#         "Arabic",
#         "French",
#         "Urdu"
#     ],
#     "homepage": "",
#     "overview": "Set in the port town of Dover in the South-East of England, Mary Hussain suddenly finds herself a widow following the unexpected death of her husband. A day after the burial, she discovers he has a secret just twenty-one miles across the English Channel in Calais.",
#     "popularity": 15.106,
#     "runtime": 89,
#     "revenue": 0,
#     "release_date": "2021-06-04",
#     "vote_average": 7.155,
#     "vote_count": 116,
#     "production_countries": [
#         "United Kingdom"
#     ]
# }
# Item 3: {
#     "title": "Alcarr\u00e0s",
#     "original_title": "Alcarr\u00e0s",
#     "budget": 0,
#     "genre": [
#         "Drama"
#     ],
#     "language": "ca",
#     "spoken_languages": [
#         "Catalan"
#     ],
#     "homepage": "https://www.alcarras-film.com/",
#     "overview": "In a small village in Catalonia, the peach farmers of the Sol\u00e9 family spend every summer together picking fruit from their orchard. But when plans arise to install solar panels and cut down trees, the members of this tight-knit group suddenly face eviction \u2013 and the loss of far more than their home.",
#     "popularity": 17.212,
#     "runtime": 120,
#     "revenue": 0,
#     "release_date": "2022-04-29",
#     "vote_average": 6.867,
#     "vote_count": 173,
#     "production_countries": [
#         "Spain"
#     ]
# }
# Item 4: {
#     "title": "Nelly and Monsieur Arnaud",
#     "original_title": "Nelly et Mr. Arnaud",
#     "budget": 0,
#     "genre": [
#         "Drama",
#         "Romance"
#     ],
#     "language": "fr",
#     "spoken_languages": [
#         "French"
#     ],
#     "homepage": "",
#     "overview": "Nelly leaves her lazy, unemployed husband to work for retired judge Mr Arnaud, forty years her senior, after he offers to clear her bills for her. While she types his memoirs the two develop a close friendship, but Arnaud becomes jealous when Nelly begins dating his good-looking young publisher.",
#     "popularity": 11.343,
#     "runtime": 106,
#     "revenue": 0,
#     "release_date": "1995-08-23",
#     "vote_average": 6.9,
#     "vote_count": 116,
#     "production_countries": [
#         "Germany",
#         "France",
#         "Italy"
#     ]
# }

# %%
# Convert the results to a DataFrame called tmdb_df with pd.DataFrame(). 
# You don't need to use json_normalize() this time because we don't have nested objects.
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df
# Out:
#                          title           original_title    budget  \
# 0         Pamela, A Love Story     Pamela, A Love Story         0
# 1             In from the Side         In from the Side         0
# 2                   After Love               After Love         0
# 3                     Alcarràs                 Alcarràs         0
# 4    Nelly and Monsieur Arnaud      Nelly et Mr. Arnaud         0
# ..                         ...                      ...       ...
# 195    Lady Chatterley's Lover  Lady Chatterley's Lover         0
# 196     The Sound of Christmas   The Sound of Christmas         0
# 197             The Inspection           The Inspection         0
# 198              Bones and All            Bones and All  18000000
# 199               My Policeman             My Policeman         0
#
#                         genre language                 spoken_languages  \
# 0               [Documentary]       en                        [English]
# 1            [Drama, Romance]       en                        [English]
# 2                     [Drama]       en  [English, Arabic, French, Urdu]
# 3                     [Drama]       ca                        [Catalan]
# 4            [Drama, Romance]       fr                         [French]
# ..                        ...      ...                              ...
# 195          [Drama, Romance]       en                        [English]
# 196         [TV Movie, Drama]       en                        [English]
# 197                   [Drama]       en       [Arabic, Spanish, English]
# 198  [Drama, Horror, Romance]       it                        [English]
# 199          [Drama, Romance]       en                        [English]
#
#                                    homepage  \
# 0    https://www.netflix.com/title/81590934
# 1         http://www.infromthesidemovie.com
# 2
# 3            https://www.alcarras-film.com/
# 4
# ..                                      ...
# 195  https://www.netflix.com/title/81476441
# 196
# 197   https://a24films.com/films/inspection
# 198        https://www.bonesandallfilm.net/
# 199    https://www.amazon.com/dp/B09Y8SHDPD
#
#                                               overview  popularity  runtime  \
# 0    In her own words, through personal video and d...      17.091      113
# 1    Mark, a new and inexperienced rugby club membe...      11.710      134
# 2    Set in the port town of Dover in the South-Eas...      15.106       89
# 3    In a small village in Catalonia, the peach far...      17.212      120
# 4    Nelly leaves her lazy, unemployed husband to w...      11.343      106
# ..                                                 ...         ...      ...
# 195  Unhappily married aristocrat Lady Chatterley b...      31.252      126
# 196  A woman facing eviction just before Christmas ...       1.872        0
# 197  Ellis French is a young, gay Black man, reject...      24.176       95
# 198  Abandoned by her father, a young woman embarks...      38.023      131
# 199  In the late 1990s, the arrival of elderly inva...      28.712      113
#
#       revenue release_date  vote_average  vote_count  \
# 0           0   2023-01-30         7.000         202
# 1           0   2022-09-16         6.780          59
# 2           0   2021-06-04         7.155         116
# 3           0   2022-04-29         6.867         173
# 4           0   1995-08-23         6.900         116
# ..        ...          ...           ...         ...
# 195         0   2022-11-22         6.542         372
# 196         0   2022-11-24         8.000           4
# 197    270613   2022-11-18         6.100          53
# 198  15100000   2022-11-18         7.076        1212
# 199         0   2022-10-20         7.731         635
#
#                            production_countries
# 0                    [United States of America]
# 1                              [United Kingdom]
# 2                              [United Kingdom]
# 3                                       [Spain]
# 4                      [Germany, France, Italy]
# ..                                          ...
# 195  [United Kingdom, United States of America]
# 196                  [United States of America]
# 197                  [United States of America]
# 198           [Italy, United States of America]
# 199  [United Kingdom, United States of America]
#
# [200 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index

# %%
# Export data to CSV without the index
